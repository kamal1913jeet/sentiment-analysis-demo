# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv("untitled.csv")

# %%
df.head()
# Out:
#                    review sentiment
# 0  This movie was amazing       pos
# 1      I loved the acting       pos
# 2         Best movie ever       pos
# 3     Fantastic storyline       pos
# 4    Wonderful experience       pos

# %%
ps = PorterStemmer()

# %%
corpus = [ ]
for review in df['review']:
  review = re.sub('[^a-zA-Z]', ' ' , review)
  review = review.lower()
  words = review.split()
  words = [ps.stem(word) for word in words
           if word not in stopwords.words('english')]
  review = ' '.join(words)
  corpus.append(review)

# %%
print("claeaned data " , corpus)
# Out:
# claeaned data  ['movi amaz', 'love act', 'best movi ever', 'fantast storylin', 'wonder experi', 'hate movi', 'worst movi ever', 'bore slow', 'wast time', 'terribl act']

# %%
tfidf = TfidfVectorizer()
x = tfidf.fit_transform(corpus).toarray()
y = df['sentiment'].values.ravel()

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42 , test_size = 0.2)

# %%
model = MultinomialNB()
model.fit(x_train , y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array(['neg', 'neg'], dtype='<U3')

# %%
acc= accuracy_score(y_test , y_pred)
acc
# Out:
# 0.5

# %%
while True:
  text = input("enter review :  (or exit)")
  if text.lower() == "exit":
    break
  text = re.sub('[^a-zA-Z]', ' ' , text)
  text = text.lower()
  words = text.split()
  words = [ps.stem(word)
         for word in words
         if word not in stopwords.words('english')]
  text = ' '.join(words)
  vector = tfidf.transform([text]).toarray()
  result = model.predict(vector)
  if result[0] == 'pos':
    print("the review is positive")
  else :
    print("the review is negative")
# Out:
# enter review :  (or exit)amazing place
# the review is positive
# enter review :  (or exit)disgusted
# the review is negative
# enter review :  (or exit)exit
